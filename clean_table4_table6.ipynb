# %%
# Dependencies
from pathlib import Path
import pandas as pd
import os

# %%
#import data file
data_file1 = Path("Resources/prevalence-of-depression-males-vs-females.csv")

# %%
data_file2 = Path("Resources/share-with-mental-or-substance-disorders-by-sex.csv")

# %%
data_file_df1 = pd.read_csv(data_file1)

# %%
data_file_df2 = pd.read_csv(data_file2)

# %%
data_file_df1.head(10)
# Out:
#         Entity      Code  Year  \
# 0     Abkhazia  OWID_ABK  2015
# 1  Afghanistan       AFG  1990
# 2  Afghanistan       AFG  1991
# 3  Afghanistan       AFG  1992
# 4  Afghanistan       AFG  1993
# 5  Afghanistan       AFG  1994
# 6  Afghanistan       AFG  1995
# 7  Afghanistan       AFG  1996
# 8  Afghanistan       AFG  1997
# 9  Afghanistan       AFG  1998
#
#    Prevalence - Depressive disorders - Sex: Male - Age: Age-standardized (Percent)  \
# 0                                                NaN
# 1                                           4.291054
# 2                                           4.293268
# 3                                           4.298265
# 4                                           4.303087
# 5                                           4.306053
# 6                                           4.307069
# 7                                           4.309518
# 8                                           4.313820
# ...

# %%
data_file_df2.head(10)
# Out:
#         Entity      Code  Year  \
# 0     Abkhazia  OWID_ABK  2015
# 1  Afghanistan       AFG  1990
# 2  Afghanistan       AFG  1991
# 3  Afghanistan       AFG  1992
# 4  Afghanistan       AFG  1993
# 5  Afghanistan       AFG  1994
# 6  Afghanistan       AFG  1995
# 7  Afghanistan       AFG  1996
# 8  Afghanistan       AFG  1997
# 9  Afghanistan       AFG  1998
#
#    Prevalence - Mental and substance use disorders - Sex: Male - Age: Age-standardized (Percent)  \
# 0                                                NaN
# 1                                          17.448695
# 2                                          17.771263
# 3                                          18.051575
# 4                                          18.275848
# 5                                          18.427490
# 6                                          18.494218
# 7                                          18.490436
# 8                                          18.467238
# ...

# %%
#rows in df1
data_file_df1.value_counts
# Out:
# <bound method DataFrame.value_counts of               Entity      Code  Year  \
# 0           Abkhazia  OWID_ABK  2015
# 1        Afghanistan       AFG  1990
# 2        Afghanistan       AFG  1991
# 3        Afghanistan       AFG  1992
# 4        Afghanistan       AFG  1993
# ...              ...       ...   ...
# 56390       Zimbabwe       ZWE  1988
# 56391       Zimbabwe       ZWE  1989
# 56392       Zimbabwe       ZWE  2020
# 56393       Zimbabwe       ZWE  2021
# 56394  Åland Islands       ALA  2015
#
#        Prevalence - Depressive disorders - Sex: Male - Age: Age-standardized (Percent)  \
# 0                                                    NaN
# 1                                               4.291054
# 2                                               4.293268
# 3                                               4.298265
# 4                                               4.303087
# ...                                                  ...
# ...

# %%
#rows in df2
data_file_df2.value_counts
# Out:
# <bound method DataFrame.value_counts of               Entity      Code  Year  \
# 0           Abkhazia  OWID_ABK  2015
# 1        Afghanistan       AFG  1990
# 2        Afghanistan       AFG  1991
# 3        Afghanistan       AFG  1992
# 4        Afghanistan       AFG  1993
# ...              ...       ...   ...
# 56624       Zimbabwe       ZWE  2018
# 56625       Zimbabwe       ZWE  2019
# 56626       Zimbabwe       ZWE  2020
# 56627       Zimbabwe       ZWE  2021
# 56628  Åland Islands       ALA  2015
#
#        Prevalence - Mental and substance use disorders - Sex: Male - Age: Age-standardized (Percent)  \
# 0                                                    NaN
# 1                                              17.448695
# 2                                              17.771263
# 3                                              18.051575
# 4                                              18.275848
# ...                                                  ...
# ...

# %%
#drop na rows in df1
# Drop rows where any of the specified columns have missing values
columns_to_check = ['Prevalence - Depressive disorders - Sex: Male - Age: Age-standardized (Percent)']  # List of column names to check for missing values

cleaned_data_file_df1 = data_file_df1.dropna(subset=columns_to_check, how='any', inplace=True)

# %%
data_file_df1.value_counts
# Out:
# <bound method DataFrame.value_counts of             Entity Code  Year  \
# 1      Afghanistan  AFG  1990
# 2      Afghanistan  AFG  1991
# 3      Afghanistan  AFG  1992
# 4      Afghanistan  AFG  1993
# 5      Afghanistan  AFG  1994
# ...            ...  ...   ...
# 56160     Zimbabwe  ZWE  2015
# 56161     Zimbabwe  ZWE  2016
# 56162     Zimbabwe  ZWE  2017
# 56163     Zimbabwe  ZWE  2018
# 56164     Zimbabwe  ZWE  2019
#
#        Prevalence - Depressive disorders - Sex: Male - Age: Age-standardized (Percent)  \
# 1                                               4.291054
# 2                                               4.293268
# 3                                               4.298265
# 4                                               4.303087
# 5                                               4.306053
# ...                                                  ...
# 56160                                           3.090039
# 56161                                           3.094447
# ...

# %%
#drop na rows in df1
# Drop rows where any of the specified columns have missing values
columns_to_check2 = ['Prevalence - Mental and substance use disorders - Sex: Male - Age: Age-standardized (Percent)', 'Prevalence - Mental and substance use disorders - Sex: Female - Age: Age-standardized (Percent)']  # List of column names to check for missing values

cleaned_data_file_df2 = data_file_df2.dropna(subset=columns_to_check2, how='any', inplace=True)

# %%
#count rows in df1
data_file_df2.value_counts
# Out:
# <bound method DataFrame.value_counts of             Entity Code  Year  \
# 1      Afghanistan  AFG  1990
# 2      Afghanistan  AFG  1991
# 3      Afghanistan  AFG  1992
# 4      Afghanistan  AFG  1993
# 5      Afghanistan  AFG  1994
# ...            ...  ...   ...
# 56392     Zimbabwe  ZWE  2013
# 56393     Zimbabwe  ZWE  2014
# 56394     Zimbabwe  ZWE  2015
# 56395     Zimbabwe  ZWE  2016
# 56396     Zimbabwe  ZWE  2017
#
#        Prevalence - Mental and substance use disorders - Sex: Male - Age: Age-standardized (Percent)  \
# 1                                              17.448695
# 2                                              17.771263
# 3                                              18.051575
# 4                                              18.275848
# 5                                              18.427490
# ...                                                  ...
# 56392                                          12.495983
# ...

# %%
data_file_df1.columns
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Prevalence - Depressive disorders - Sex: Male - Age: Age-standardized (Percent)',
#        'Prevalence - Depressive disorders - Sex: Female - Age: Age-standardized (Percent)',
#        'Population (historical estimates)', 'Continent'],
#       dtype='object')

# %%
data_file_df2.columns
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Prevalence - Mental and substance use disorders - Sex: Male - Age: Age-standardized (Percent)',
#        'Prevalence - Mental and substance use disorders - Sex: Female - Age: Age-standardized (Percent)',
#        'Population (historical estimates)', 'Continent'],
#       dtype='object')

# %%
df_merge = data_file_df1.merge(data_file_df2, left_on=['Entity', 'Code', 'Year'], right_on=['Entity', 'Code', 'Year'])

# %%
df_merge.head(100)
# Out:
#             Entity Code  Year  \
# 0      Afghanistan  AFG  1990
# 1      Afghanistan  AFG  1991
# 2      Afghanistan  AFG  1992
# 3      Afghanistan  AFG  1993
# 4      Afghanistan  AFG  1994
# ..             ...  ...   ...
# 95  American Samoa  ASM  2001
# 96  American Samoa  ASM  2002
# 97  American Samoa  ASM  2003
# 98  American Samoa  ASM  2004
# 99  American Samoa  ASM  2005
#
#     Prevalence - Depressive disorders - Sex: Male - Age: Age-standardized (Percent)  \
# 0                                            4.291054
# 1                                            4.293268
# 2                                            4.298265
# 3                                            4.303087
# 4                                            4.306053
# ..                                                ...
# 95                                           2.330642
# 96                                           2.331761
# 97                                           2.331426
# ...

# %%
df_merge.to_csv('merge_4_6_cleaned.csv')
